# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
# Out:
# C:\Users\ashut\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
x=df.iloc[:,:-1]
y=df[['Outcome']]

# %%
x,y
# Out:
# (     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
#  0              6      148             72             35        0  33.6
#  1              1       85             66             29        0  26.6
#  2              8      183             64              0        0  23.3
#  3              1       89             66             23       94  28.1
#  4              0      137             40             35      168  43.1
#  ..           ...      ...            ...            ...      ...   ...
#  763           10      101             76             48      180  32.9
#  764            2      122             70             27        0  36.8
#  765            5      121             72             23      112  26.2
#  766            1      126             60              0        0  30.1
#  767            1       93             70             31        0  30.4
#
#       DiabetesPedigreeFunction  Age
#  0                       0.627   50
#  1                       0.351   31
#  2                       0.672   32
#  3                       0.167   21
#  4                       2.288   33
#  ..                        ...  ...
#  763                     0.171   63
#  764                     0.340   27
#  765                     0.245   30
#  766                     0.349   47
#  767                     0.315   23
#
#  [768 rows x 8 columns],
#       Outcome
#  0          1
#  1          0
#  2          1
#  3          0
#  4          1
#  ..       ...
#  763        0
#  764        0
#  765        0
#  766        1
#  767        0
#
#  [768 rows x 1 columns])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
x,y, test_size=0.30)

# %%
from sklearn.svm import SVC

# %%
# for classified data
model = SVC()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\ashut\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([-0.05211088,  0.58350343,  0.71301319,  0.6209072 ,  0.05320391,
#         0.247294  ,  0.01668426,  0.64193434,  0.71595273,  0.00257833,
#         0.05536896,  0.74265813,  0.1087239 ,  0.16187713,  0.36372457,
#         0.03508607,  0.46390362,  0.0450885 ,  0.3259439 ,  0.11339444,
#         0.71449441,  0.58295445, -0.00617439,  0.01751054,  0.31123294,
#         0.33685476,  0.18263148,  0.22942035,  0.73283224,  0.34391236,
#         0.39618832,  0.29151783,  0.58234548,  0.69404724,  0.15201336,
#        -0.04159607,  0.80214424,  0.11573964,  0.21454543,  0.31586434,
#         0.15531962,  0.67968909,  0.94461411,  0.4214083 ,  0.266866  ,
#         0.00864468,  0.70236708,  0.27819876, -0.1421385 ,  0.3401018 ,
#        -0.03245187,  0.52915822,  0.71735789,  0.79577967,  0.28759951,
#         0.28995173,  0.11293091, -0.06844302,  0.46501609,  0.58392319,
#         0.34944358,  0.58442211,  0.17567287, -0.03525735,  0.19298205,
#        -0.07663923,  0.34654617,  0.42857216,  0.71073568,  0.23776075,
#         0.17796796,  0.47444036,  0.1880699 ,  0.09023541,  0.6290027 ,
#        -0.10387844,  0.19021203,  0.02177052,  0.24269542,  0.26728475,
#         0.68782444,  0.36630139,  1.21002071,  0.00154005,  0.19958705,
#         0.64083487,  0.19688134,  0.0071019 , -0.87273664,  1.13770784,
#         0.15195336,  0.30865797, -0.02206511, -0.02345234, -0.04748586,
#         0.78836209,  0.23197908,  0.33164869,  0.71111384,  0.08790115,
#         0.49492596,  0.14569307, -0.04746345,  0.30033429,  0.34586165,
#         0.33624746,  0.16454281,  0.3965736 ,  0.80673782,  0.17392043,
#         0.31469846,  0.46133097,  0.2957414 , -0.07326835, -0.0720688 ,
#        -0.06267161,  0.7140599 ,  0.74427358,  0.00815356,  0.6173891 ,
#         1.08521267,  0.39177592,  0.34758681,  0.15804104,  0.45973555,
#         0.91939643,  0.36638934,  0.98915376,  0.18100748,  0.5331087 ,
#         0.77025634,  0.59327861,  0.09083979,  0.3084734 ,  0.38446276,
#         0.8695703 ,  0.10133677, -0.06863996,  0.5394493 , -0.06513527,
#         0.12107352,  0.19998836, -0.19417425,  0.73332617,  0.37741963,
#         0.0944075 ,  0.48535975,  0.14201648,  0.69969337,  0.01910615,
#         0.32339505,  0.29147424,  0.23218302,  0.63014131, -0.16047303,
#         0.04581126,  0.42972726,  0.37217378,  0.05275552, -0.01692051,
#         0.24113171, -0.19558115,  0.21938145,  0.27529854,  0.14718186,
#         0.70770976, -0.05745165, -0.56842044,  0.15212148,  0.47130954,
#         0.32306467,  0.20129616,  0.51863289,  0.17177879,  0.40256005,
#         1.12493802,  0.5906135 ,  0.30451535,  0.1626308 ,  0.18290753,
#         0.3141337 ,  0.4656784 ,  0.59291183,  0.30957829, -0.22923164,
#         0.04894602,  0.77043166,  0.78547754,  0.15292828,  0.10838999,
#         0.02319265,  0.39692209,  0.01510547,  0.66435957,  0.21485106,
#         0.28380217,  0.47731983,  0.62190221,  0.55717575,  0.79136684,
#         0.10984751, -0.19039734,  0.58234996,  0.7176636 , -0.11385908,
#         0.89726176, -0.01547749,  0.21138362,  0.73066016,  0.31417403,
#         0.5586044 ,  0.91896478,  0.56145305,  0.26382165,  0.15193272,
#         0.33719621, -0.11738023,  0.76332776,  0.38268753,  0.43905617,
#         0.7239416 ,  0.27463776,  0.75319437,  0.49013225, -0.15867779,
#         0.18338942,  1.03070383,  0.42582313,  0.25047689, -0.11105928,
#         0.30906216])

# %%
accuracy_score(y_test,pred)
# Out:
# 0.7359307359307359

# %%
from sklearn.metrics import  confusion_matrix
confusion_matrix(y_test,pred)
# Out:
# array([[131,  24],
#        [ 37,  39]], dtype=int64)

# %%
model.support_vectors_
# Out:
# array([[2.00e+00, 1.29e+02, 7.40e+01, ..., 3.32e+01, 5.91e-01, 2.50e+01],
#        [1.00e+01, 1.79e+02, 7.00e+01, ..., 3.51e+01, 2.00e-01, 3.70e+01],
#        [0.00e+00, 1.07e+02, 7.60e+01, ..., 4.53e+01, 6.86e-01, 2.40e+01],
#        ...,
#        [4.00e+00, 1.56e+02, 7.50e+01, ..., 4.83e+01, 2.38e-01, 3.20e+01],
#        [5.00e+00, 1.30e+02, 8.20e+01, ..., 3.91e+01, 9.56e-01, 3.70e+01],
#        [2.00e+00, 1.02e+02, 8.60e+01, ..., 4.55e+01, 1.27e-01, 2.30e+01]])
