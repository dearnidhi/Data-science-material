# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Housing_Data.csv')
df
# Out:
#             Income       Age     Rooms  Bedrooms    Population         Price  \
# 0     79545.458574  5.682861  7.009188      4.09  23086.800503  1.059034e+06
# 1     79248.642455  6.002900  6.730821      3.09  40173.072174  1.505891e+06
# 2     61287.067179  5.865890  8.512727      5.13  36882.159400  1.058988e+06
# 3     63345.240046  7.188236  5.586729      3.26  34310.242831  1.260617e+06
# 4     59982.197226  5.040555  7.839388      4.23  26354.109472  6.309435e+05
# ...            ...       ...       ...       ...           ...           ...
# 4995  60567.944140  7.830362  6.137356      3.46  22837.361035  1.060194e+06
# 4996  78491.275435  6.999135  6.576763      4.02  25616.115489  1.482618e+06
# 4997  63390.686886  7.250591  4.805081      2.13  33266.145490  1.030730e+06
# 4998  68001.331235  5.534388  7.130144      5.44  42625.620156  1.198657e+06
# 4999  65510.581804  5.992305  6.792336      4.07  46501.283803  1.298950e+06
#
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
df.drop('Address',axis=1,inplace=True)

# %%
x=df.drop('Price',axis=1)
y=df[['Price']]
x,y
# Out:
# (            Income       Age     Rooms  Bedrooms    Population
#  0     79545.458574  5.682861  7.009188      4.09  23086.800503
#  1     79248.642455  6.002900  6.730821      3.09  40173.072174
#  2     61287.067179  5.865890  8.512727      5.13  36882.159400
#  3     63345.240046  7.188236  5.586729      3.26  34310.242831
#  4     59982.197226  5.040555  7.839388      4.23  26354.109472
#  ...            ...       ...       ...       ...           ...
#  4995  60567.944140  7.830362  6.137356      3.46  22837.361035
#  4996  78491.275435  6.999135  6.576763      4.02  25616.115489
#  4997  63390.686886  7.250591  4.805081      2.13  33266.145490
#  4998  68001.331235  5.534388  7.130144      5.44  42625.620156
#  4999  65510.581804  5.992305  6.792336      4.07  46501.283803
#
#  [5000 rows x 5 columns],
#               Price
#  0     1.059034e+06
#  1     1.505891e+06
#  2     1.058988e+06
#  3     1.260617e+06
#  4     6.309435e+05
#  ...            ...
#  4995  1.060194e+06
#  4996  1.482618e+06
#  4997  1.030730e+06
#  4998  1.198657e+06
#  4999  1.298950e+06
#
#  [5000 rows x 1 columns])

# %%
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\ashut\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
from sklearn.svm import SVR

# %%
model=SVR(kernel='linear')

# %%
c
# Out:
# C:\Users\ashut\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([1254357.38940127, 1331253.94791205, 1113808.98249037, ...,
#        1381471.8838671 , 1838557.99208148, 1087402.12938006])

# %%
model.score(x,y)
# Out:
# 0.5936847808620598

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 180774.65257320297
